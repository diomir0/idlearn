# %%
import os
import re
from collections import Counter
import json
import pymupdf


def get_toc(doc):
    toc = doc.get_toc()  # format: [level, title, page]
    toc_with_end = []

    for i, (level, title, start_page) in enumerate(toc):
        # Look ahead for the next section at same or higher level
        end_page = doc.page_count  # default: end of document

        for j in range(i + 1, len(toc)):
            next_level, _, next_start = toc[j]
            if next_level <= level:
                end_page = toc[j][2]
                break
        title = re.sub(r'(\\u200[0-9a])+', ' ', re.sub(r'(\\xa[d0])+', '',title))
        toc_with_end.append(
            (level,
            title,
            start_page,
            end_page)
        )

    return toc_with_end
    

# Getting the info from PDF
def info_extract(doc):
    # Get Table of Contents
    toc = get_toc(doc)
    sec_names = [toc[i][1].lower() for i in range(len(toc))]
    
    # Extracting the sections 
    sections = []
    for sec in toc:
        if sec[0]==2:
            sections.append(sec[1].lower()) 

    # Defining page height from first page
    pheight = doc[0].rect.height
    # Defining frame height 
    pframe = 50
    
    # Computing dominant text size throughout the document
    main_size = get_main_size(doc)
    main_font = get_main_font(doc)

    return (toc, pheight, pframe, main_size, main_font)


# Function returning the main text's font of a document
def get_main_size(doc):
    font_sizes = []
    for page in doc:
        text_dict = page.get_text("dict")
        blocks = text_dict["blocks"]
        for block in blocks:
            for line in block.get("lines", []):
                for span in line.get("spans", []):
                    if not re.match(r'[\s\t]+', span["text"]): font_sizes.append(round(span["size"]))
    size_count = Counter(font_sizes)
    dominant_size = size_count.most_common(2)
    if (dominant_size[1][0] > dominant_size[0][0] and dominant_size[1][1] > dominant_size[0][0]/2):
        main_size = round(dominant_size[1][0]) 
    else:
        main_size = round(dominant_size[0][0]) 

    return main_size


def get_main_font(doc):
    fonts = []
    for page in doc:
        text_dict = page.get_text("dict")
        blocks = text_dict["blocks"]
        for block in blocks:
            for line in block.get("lines", []):
                for span in line.get("spans", []):
                    if not re.match(r'[\s\t]+', span["text"]): fonts.append(span["font"])
    font_count = Counter(fonts)
    dominant_font = font_count.most_common(1)

    return dominant_font


def tocL2tocD(toc_list):
    root = {}
    stack = [(0, root)]  # stack of (level, current_dict)

    for level, title, startpage, endpage in toc_list:
        current_dict = {}
        while stack and level <= stack[-1][0]:
            stack.pop()
        stack[-1][1][(level, title, startpage, endpage)] = {"_page": (startpage, endpage), "_sub": current_dict}
        stack.append((level, current_dict))

    def cleanup(d):
        return {
            k: cleanup(v["_sub"]) if v["_sub"] else {"_page": v["_page"]}
            for k, v in d.items()
        }

    return cleanup(root)


def get_parent(secname, toc_dict, parent=None):
    for key, value in toc_dict.items():
        if key == secname:
            return parent
            
        if isinstance(value, dict):
            child_dict = value
            result = get_parent(secname, child_dict, key)
            if result:
                return result
    return None


def get_ancestry(target, d, path=None):
    if path is None:
        path = []

    for key, value in d.items():
        current_path = path + [key]

        if key == target:
            return current_path

        # Check if value is a dict and has further nested items
        if isinstance(value, dict):
            child_dict = value if "_page" not in value else {}
            result = get_ancestry(target, child_dict, current_path)
            if result:
                return result

    return None  # Target not found


def get_span(line):
    spans = []
    span = {'text': '', 'font': '', 'size': 0}
    for s in line.get("spans", []):
        if not re.match(r'[\s\t]+', s["text"]):
            s["text"] = re.sub(r'(\\u200[0-9a])+', ' ', re.sub(r'(\\xa[d0])+', '',s["text"]))
            if span["text"] == '': 
                span["text"] = s["text"]
                span["font"] = s["font"]
                span["size"] = s["size"]
            else: 
                if (s["font"] == span["font"] and 
                    (s["size"] == span["size"] or (s["size"] < span["size"] and len(s["text"]) <= 3))):
                    span["text"] = span["text"] + ' ' + s["text"] 
                    span["size"] = s["size"]
                elif (line.get("spans", [])[line.get("spans", []).index(s)-1] != ' ' and 
                      span["font"] == s["font"] and 
                      s["size"] < span["size"]):
                    span["text"] = span["text"] + s["text"]
                    span["size"] = s["size"]
                else:
                    break
    span["text"] = re.sub(r'\s+([.,:?!])', r'\1', span["text"])
    return span


def detect_captions(span):
    if (re.match(r'Fig(ure)?\.(\s)?(\d+)?(\w+)?(\s+)?:', span["text"]) or 
        re.match(r'Table(\s)?(\d+)?(\w+)?(\s+)?:', span["text"])):
        return True
    else:
        return None

# %%
# Function extracting and structuring the text from PDF
def text_extract(doc, sections):
    
    toc, pheight, pframe, main_size, main_font = info_extract(doc)
    toc_dict = tocL2tocD(toc)

    main_text = {}

    for section in sections:
        start_page = section[2]
        end_page = section[3]
        level = section[0]
        parent = get_parent(section, toc_dict)
        title_format = {'font': main_font, 'size': main_size}
        
        parents_siblings_sections = [sec for sec in toc[toc.index(section):] if (sec[0]<level or 
                                                                                 (sec[0]==level and get_parent(sec, toc_dict) == parent))]
        next_section = parents_siblings_sections[parents_siblings_sections.index(section)+1]

        if (parent in sections) and (parent is not None):
            continue

        key = ""
        value = ""
        pblocks = []

        for i in range(start_page, end_page+1):
            page = doc.load_page(i-1)
            pblocks.append(page.get_text("dict")["blocks"])

        split_title = False

        stop = False
        
        for blocks in pblocks:
            if stop: break
            bflag = False
            for block in blocks:
                if bflag or stop: break  
                # Removing header and footer blocks
                if block["bbox"][1] > pframe and block["bbox"][3] < pheight-pframe:
                    for line in block.get("lines", []):
                        span = get_span(line)
                        print(span)

                        if detect_captions(span): 
                            bflag = True
                            break
                        
                        # Detect titles
                        if (span["font"] != main_font or span["size"] > main_size
                            and block.get("lines", []).index(line) < 4):

                            if (re.search(rf"{re.escape(span['text'].lower().strip(',.:?!'))}", section[1].lower().strip(',.:?!')) or
                                re.search(rf"{re.escape(section[1].lower().strip(',.:?!'))}", span['text'].lower().strip(',.:?!')) and
                                key == ''
                               ):
                                key = section[1]
                                value = ""
                                continue
                            
                        # Check if the content if the line corresponds to the title
                        if (re.match(rf"((chapter)?(part)?(\d+\.\s?)+)?{section[1].lower().strip()}", f"{span["text"].lower().strip('.:')}") # Check if line text corresponds to section title
                              and key == ''  # Check if key is empty
                             ):
                            key = section[1]
                            value = ""
                            title_format = {'font': span["font"], 'size': round(span["size"])}
                            continue
                                 
                        # In case the title spans multiple lines in the text, check if the whole title can be found in first line
                        elif (re.search(rf"{re.escape(span['text'].lower())}", section[1].lower().strip()) # Check if section name begins with line text
                              #and len(span["text"].lower().split()) > 1  # Avoid single words like 'the' to be taken as false positive
                              #and len(section[1].split()) > 2  # Apply the above condition only if the section title is longer than 2 words
                              and key == '' # Check if key is empty
                             ):
                            key = section[1]
                            value = ""
                            split_title = True
                            title = span["text"].lower().strip()
                            continue
                        
                        # Avoid încluding the following title lines to be taken as main text
                        elif split_title:
                            title = title + ' ' + span["text"].lower().strip()
                            if title == section[1].lower().strip():
                                title_format = {'font': span["font"], 'size': round(span["size"])}
                                split_title = False
                                continue
                            else:
                                continue
                        
                        # Stop adding text to the dictionary when encountering the next same-level section
                        if ((next_section[1].lower().strip().startswith(span["text"].lower().strip('.:'))
                             and span["size"] > main_size
                             and span["font"] == title_format["font"]
                             and len(span["text"].lower().split()) >= 1
                             and block.get("lines", []).index(line) < 4) # Avoid single words like 'the' to be taken as false positive
                            or 
                            (span["text"].lower().strip('.:').startswith(next_section[1].lower().strip())
                                and ((span["font"] == title_format["font"] and span["size"] == title_format["size"]) or
                                     (round(span["size"]) > title_format["size"]))
                             and block.get("lines", []).index(line) < 4)
                           ):
                            stop = True
                            break
                        
                        # Get the block's text as dict value based on the font size
                        for span in line.get("spans", []):
                            if (span["text"].lower().strip() in ("references", "bibliography") and
                                (round(span["size"]) > main_size)):
                                stop = True
                                break
                                
                            # Introducing a tolerance of font size of 0.5 for small variations in the text body
                            if ((#round(span["size"]) == main_size and 
                                not any([sec[1].lower() == "materials and methods" for sec in get_ancestry(section, toc_dict)])  
                                and key != "")
                                or(round(span["size"]) >= main_size-1 and round(span["size"]) <= main_size
                                   and any([sec[1].lower() == "materials and methods" for sec in get_ancestry(section, toc_dict)]))
                               ):
                                text = span["text"]
                                # Repairing lines
                                if (len(value) > 1 and (value[-1] == "-" or value[-1] == "ﬁ" or value[-1] == 'ﬂ') 
                                    or (text == 'ﬁ' or text == 'ﬂ')):
                                    if value[-1] == '-': value = value[:-1] 
                                    value = value + text
                                else: 
                                    value = value + ' ' + text 
                            
                if (key != "" and value != ""):
                    value = re.sub(r'(\\u200[0-9a])+', ' ', re.sub(r'(\\xa[d0])+', '',value))
                    # Removing references
                    value = re.sub(r'(;\s)?\[\s(\d(\s,\s+)?)+\s\]', '', value.strip())
                    value = re.sub(r'(;\s)?\[\s\d+\s–\s\d+\s\]', '', value.strip())
                    # Formatting spaces surrounding commas, dots, and parentheses
                    value = re.sub(r'\s+([,.!?:])', r'\1', value.strip())
                    value = re.sub(r'\(\s', '(', value.strip())
                    value = re.sub(r'\s\)', ')', value.strip())
                    # Removing multiple spaces (strip method fails)
                    value = re.sub(r'\s+', ' ', value.strip())
                    # Replacing the 'ﬁ' and 'ﬂ' characters with correct "fi" string
                    value = re.sub(r'ﬁ', 'fi', value.strip())
                    value = re.sub(r'ﬂ', 'fl', value.strip())
                    value = value.replace('\xad ', '').replace('\xa0', '').replace('\u2003', ' ')
                
                    main_text[key] = value
        
    return main_text

# %%
doc = pymupdf.open("/home/diomir0/Documents/books/med_sci/Anne Harrington - Mind Fixers - Psychiatry’s Troubled Search for the Biology of Mental Illness (2019).epub")

# %%
toc = get_toc(doc)
[print(i, sec) for i, sec in enumerate(toc)]
# Out:
# 0 (1, 'Cover', 1, 2)
# 1 (1, 'Title', 2, 4)
# 2 (1, 'Contents', 4, 6)
# 3 (1, 'Introduction: Our Biological Enthusiasms', 6, 14)
# 4 (1, 'Part I: Doctors’ Stories', 14, 148)
# 5 (2, 'Chapter 1: Betting On Anatomy', 15, 45)
# 6 (2, 'Chapter 2: Biology In Disarray', 45, 87)
# 7 (2, 'Chapter 3: A Fragile Freudian Triumph', 87, 119)
# 8 (2, 'Chapter 4: Crisis And Revolt', 119, 148)
# 9 (1, 'Part II: Disease Stories', 148, 252)
# 10 (2, 'Chapter 5: Schizophrenia', 149, 192)
# 11 (2, 'Chapter 6: Depression', 192, 225)
# 12 (2, 'Chapter 7: Manic-Depression', 225, 252)
# 13 (1, 'Part III: Unfinished Stories', 252, 276)
# 14 (2, 'Chapter 8: False Dawn', 253, 276)
# 15 (1, 'Afterthoughts', 276, 282)
# 16 (1, 'Notes', 282, 352)
# 17 (1, 'Guide to Further Reading', 352, 363)
# 18 (1, 'Index', 363, 409)
# 19 (1, 'Acknowledgments', 409, 411)
# 20 (1, 'Also by Anne Harrington', 411, 412)
# 21 (1, 'Copyright', 412, 412)
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
sections = [toc[3]]
#print(info_extract(doc))
text_extract(doc, sections)
# Out:
# {'text': 'INTRODUCTION', 'font': 'Nimbus Sans Regular', 'size': 16.5}
# {'text': 'Our Biological Enthusiasms', 'font': 'Nimbus Sans Bold', 'size': 22.0}
# {'text': 'IN 1978 THE HISTORIAN AND SOCIAL CRITIC MARTIN GROSS APPEARED', 'font': 'Nimbus Sans Regular', 'size': 8.25}
# {'text': 'television show ', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'Psychological Society', 'font': 'Charis SIL Italic', 'size': 11.0}
# {'text': 'with psychoanalytic practices, he prophesied that “within the next', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'ten years...\xa0psychiatry will come out of the dark ages, will drop all', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'the nonsense and expertise about human behavior of which they', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'know absolutely nothing that my grandmother didn’t know, if they', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'know that much, and will turn to medicine.” His interlocutors were', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'more than a little skeptical and even amused by his passion. One of', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'them, the newspaper publisher and editor Sylvan Meyer, asked', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'ironically how Gross thought that “a major body of science that’s', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'been in business for a fairly long time could be disposed of so', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'quickly.” 1', 'font': 'Charis SIL Regular', 'size': 7.699999809265137}
# {'text': 'It was Gross, though, who had the last laugh, and he did not', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'have to wait ten years, or even five, to have it. Just two years after', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'he sounded off on ', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'meeting of the American Psychiatric Association and the major', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'changes in process:', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'A year later, in 1981, two prominent psychiatrists predicted in', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'Psychology Today', 'font': 'Charis SIL Italic', 'size': 11.0}
# {'text': 'patients with emotional problems were treated, not with mere talk,', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'but in a proper medical fashion—with “drugs [that]...\xa0normalize a', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'deep abnormality close to underlying causes.” 3', 'font': 'Charis SIL Regular', 'size': 7.699999809265137}
# {'text': 'that, the ', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'about mental disorders was on the verge of fundamental change:', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': '“During the past decade—barely a blink of the eye in the history of', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'scientific ', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'research—scientists ', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'have ', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'unlocked ', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'the ', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'doors ', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'to', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'understanding the body’s most complicated and baffling organ: the', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'brain....\xa0It is as if a small trail painstakingly carved through a', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'jungle over the course of centuries had been, within the space of 10', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'years, turned into a superhighway.” 4', 'font': 'Charis SIL Regular', 'size': 7.699999809265137}
# {'text': 'By 1984, the Pulitzer Prize–winning science journalist Jon', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'Franklin felt able to drop all pretense of deference toward the', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'alleged opposition and to mock psychoanalysis as “the bumbling', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'and sometimes humorous stepchild of modern science.” The future', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'of psychiatry, he said, lay not with the old talk therapists and', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'analysts but with a new generation of clinician-scientists he called', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': '“the mind-fixers”: “research psychiatrists...\xa0working quietly in', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'laboratories, dissecting the brains of mice and men and teasing out', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'the chemical formulas that unlock the secrets of the mind.” 5', 'font': 'Charis SIL Regular', 'size': 7.699999809265137}
# {'text': 'By 1988—a mere ten years after Gross had been gently mocked', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'on ', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'discipline seemed complete. That fall the psychiatrist Samuel Guze', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'gave a lecture at London’s Maudsley Hospital provocatively titled:', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': '“Biological Psychiatry: Is There Any Other Kind?” His answer was', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'implied in the title: of course not. Psychiatry was a branch of', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'medicine, and all medicine was “applied biology,” end of story. “I', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'believe,” he concluded, “that continuing debate about the biological', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'basis of psychiatry is derived much more from philosophical,', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'ideological and political concerns than from scientific ones.” 7', 'font': 'Charis SIL Regular', 'size': 7.699999809265137}
# {'text': 'All this added up to nothing less than a palace revolution in', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'American ', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'psychiatry, ', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'an ', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'astonishingly ', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'rapid, ', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': '180-degree', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'turnaround in understanding and approaches to ailments of the', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'mind. Why did it happen? What caused an entire profession to', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'reorient itself so quickly and so completely?', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'For the psychiatrists who heralded these developments in the', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': '1980s, the answers seemed clear. In the late nineteenth century,', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'they believed, the field of psychiatry—especially in German-', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'speaking Europe—had actually been on the right track. Under the', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'leadership of Theodor Meynert and Emil Kraepelin, it had pursued a', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'robust biological research program. Unfortunately, the Freudians', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'had come along, turned everyone’s heads, and led the field into a', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'scientific wasteland for more than half a century. Finally, however,', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'exciting new developments in neuroscience, genetics, and', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'psychopharmacology had changed things. Irrefutable evidence that', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'mental disorders were brain diseases had emboldened a new', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'generation of biological psychiatrists to overthrow the Freudians', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'and to bring back the brain as the primary object of psychiatric', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'research, diagnosis, and treatment. It was a simple explanatory', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'story, one with clear heroes and villains, and above all a', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'satisfyingly happy ending. 8', 'font': 'Charis SIL Regular', 'size': 7.699999809265137}
# {'text': 'Put another way, American psychiatry’s 1980s biological', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'revolution was what people in my field call an “actor’s category.” 9', 'font': 'Charis SIL Regular', 'size': 7.699999809265137}
# {'text': 'We confuse ourselves if we try invoking it to make analytic sense of', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'developments in this period, simply because the period was not', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'marked by any revolutionary new understandings of the biology of', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'mental illness. If, though, we understand that it was instead a vision', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'of psychiatry’s identity and destiny that was summoned rhetorically', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'into existence in the 1980s, then we can start asking questions', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'about why it was summoned, and all the ways in which it became a', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'critically important mindset and belief system under which all sorts', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'of stakeholders carried out—and still carry out—their business.', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'We can also understand why it left behind such an', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'unsatisfactory legacy. For make no mistake: today one is hard-', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'pressed to find anyone knowledgeable who believes that the so-', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'called biological revolution of the 1980s made good on most or', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'even any of its therapeutic and scientific promises. Criticism of the', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'enterprise has escalated sharply in recent decades. It is now', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'increasingly clear to the general public that it overreached,', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'overpromised, overdiagnosed, overmedicated, and compromised its', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'principles.', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'Also in 2013, Insel’s colleague, Steven Hyman—another former', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'NIMH director—sounded the alarm about the abandonment of the', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'field by the pharmaceutical industry. In spite of all the 1980s', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'declarations of revolutionary science driving change, Hyman noted,', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'psychiatry had actually had no good new ideas about molecular', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'targets for diagnoses and treatments ', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'consequence, ', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': '“the ', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'underlying ', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'science ', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'remains ', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'immature', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'and...\xa0therapeutic development in psychiatry is simply too', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'difficult and too risky.” 11', 'font': 'Charis SIL Regular', 'size': 7.699999809265137}
# {'text': 'It is clear that we need a new story. This book is an effort to', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'offer one, to take a deep dive into our long effort to understand the', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'biological basis of mental illness and above all why it has been so', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'troubled. Except for  Chapter 1, my geographical focus is primarily', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'American, because I believe the current confusion, frustrated hopes,', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'and anger over the state of biological psychiatry in this country cry', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'out most urgently for historical perspective and illumination.', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'In a development filled with irony, however, the years of', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'Freudian dominance also witnessed virtually all the scientific and', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'treatment developments to which the biological psychiatrists would', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'later point as evidence that they should be in charge. All the major', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'categories of drugs still used today in psychiatry were discovered', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'then—to be sure, largely through serendipity and opportunism.', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'There was important early research on the functioning of', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'neurotransmitters as chemical messengers within the brain. There', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'was influential genetic research. All this happened, yet the', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'Freudians stayed in power. On fundamental issues, no minds were', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'changed that did not want to be changed.', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'What finally catalyzed change was not some new piece of', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'decisive science but a sense of professional crisis. By the 1970s, a', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'range of rebels and critics had emerged who, in different ways, had', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'grievances with the Freudian old guard. They accused the Freudians', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'of collusion with immoral political causes, of racism and sexism, of', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'blaming and abandoning families, and of bringing the field as a', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'whole to the brink of professional suicide through grandiosity and', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'systematic lack of rigor. The situation was so bad, clinicians pointed', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'out, that large segments of the public were no longer even sure that', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'mental illness existed!', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'Part I', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'question of how a reform in diagnostic practices alone could have', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'served as the basis for a ', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'candidate findings held up by the biological psychiatrists to support', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'their new claims to authority and how did they come to be? How', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'persuasive were they? Where did they come from? There must have', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'been more to it, and there was.  Part II', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'through psychiatry’s struggle to discover a biological basis of', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'mental illness, seen this time through the lens of three specific', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'diseases: schizophrenia, depression, and bipolar disorder (manic-', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'depression). Each story is quite distinct. The science in play was', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'different for each, and different events catalyzed the drive both to', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'biologize and to squelch rival perspectives. Drugs were important in', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'different ways. Families and the public mattered in different ways.', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'Patients had different kinds of experiences. In other words, one', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'argument of this book is that the history of psychiatry’s efforts to', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'understand mental illness biologically is a pluralistic one. It cannot', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'be told in a simple, linear way.', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'Part III', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'biological psychiatry of the 1980s began to unravel in the 1990s', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'and especially in the new millennium. I argue that this happened,', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'not just because the gap between hype and the state of scientific', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'understanding was too great to bridge (though it was), but also', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'because of a critical error that the original revolutionaries had', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'made. Instead of reflecting on the extent to which the Freudians', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'had lost credibility by insisting that they could be experts on', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'everything, the new generation of biological revolutionaries', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'repeated their mistake: they declared themselves the ', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'everything. No one suggested that it might be prudent to decide', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'which forms of mental suffering were best served by a medical', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'model, and which might be better served in some other way.', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'Revolutionaries don’t cede ground.', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'I have written this book because I believe history matters. We', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'perhaps don’t need history to see that psychiatry today is not a', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'stable enterprise marked by a consensus about mission, but rather a', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'fraught one, where rhetoric still far outstrips substance, where trust', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'is fragile, and where the path forward is unclear. But we do need', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'history to understand how we came to be where we are now and', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'therefore what might need to happen next. Heroic origin stories and', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'polemical counterstories may give us momentary emotional', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'satisfaction by inviting us to despise cartoonish renderings of our', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'perceived rivals and enemies. The price we all pay, though, is', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'tunnel vision, mutual recrimination, and stalemate. For the sake not', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'just of the science but of all the suffering people whom the science', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'should be serving, it is time for us all to learn and to tell better,', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'more honest stories.', 'font': 'Charis SIL Regular', 'size': 11.0}
# {'text': 'PART I', 'font': 'Nimbus Sans Regular', 'size': 33.0}
# {'text': 'DOCTORS’', 'font': 'Nimbus Sans Bold', 'size': 27.5}
# {'text': 'STORIES', 'font': 'Nimbus Sans Bold', 'size': 27.5}
# {}

# %%
page = doc.load_page(5)
for i, block in enumerate(page.get_text("dict")["blocks"]):
    print(i)
    for line in block.get("lines", []):
        for spans in line.get("spans", []):
            if not re.match(r'[\s\t]+', spans["text"]): print(spans)

# %%
test = "Blue boo: here's it"
re.search(r'boo', test)
# Out:
# <re.Match object; span=(5, 8), match='boo'>
